# %%
import pandas as pd

# %%
excel_file = "./smallruminants/AHLE scenario parameters SMALLRUMINANTS.xlsx"

df = pd.read_excel(excel_file)
df.head(10)
# Out:
#                     AHLE Parameter              Notes CLM_S_Current  \
# 0                       Num_months                NaN            12
# 1             # Initial population                NaN           NaN
# 2                          N_NF_t0  # Neonatal female       2070822
# 3                          N_NM_t0    # Neonatal male       2070822
# 4                          N_JF_t0  # Juvenile female       1915971
# 5                          N_JM_t0    # Juvenile male       1147386
# 6                          N_AF_t0     # Adult female      14049629
# 7                          N_AM_t0       # Adult male       3048715
# 8                              NaN                NaN           NaN
# 9  ## Growth rate N -> J and J-> A           0.166667           NaN
#
#   CLM_S_Ideal CLM_S_all_mortality_zero CLM_S_all_mort_25_imp  \
# 0          12                       12                    12
# 1         NaN                      NaN                   NaN
# ...

# %%
keys = df["AHLE Parameter"].tolist()
keys = list(map(str, keys))
keys
# Out:
# ['Num_months',
#  '# Initial population',
#  'N_NF_t0',
#  'N_NM_t0',
#  'N_JF_t0',
#  'N_JM_t0',
#  'N_AF_t0',
#  'N_AM_t0',
#  'nan',
#  '## Growth rate N -> J and J-> A',
#  'Beta',
#  'nan',
#  '# Fertility',
#  'part',
#  'prolif',
#  'nan',
#  '# lactation',
#  'prop_F_milked',
#  'lac_duration',
#  'avg_daily_yield_ltr',
#  'milk_value_ltr',
#  'nan',
#  '# Offtake',
#  '## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0',
#  '## offtake must = offtake + dif between NNFt0 etc and NJF current',
#  'GammaF ',
#  'GammaM ',
#  'nan',
#  '# Mortality ## informed from META analysis',
#  'AlphaN',
#  'AlphaJ',
#  'AlphaF',
#  'AlphaM',
#  'nan',
#  '# Culls',
#  'CullF',
#  'CullM',
#  'nan',
#  '## Production parameters (kg)',
#  'nan',
#  '# Liveweight conversion (kg) ## Informed from META analysis',
#  'lwNF  ',
#  'lwNM  ',
#  'lwJF ',
#  'lwJM ',
#  'lwAF ',
#  'lwAM ',
#  'nan',
#  '# carcase yeild',
#  'ccy ',
#  'nan',
# ...

# %%
df_val = df.iloc[:,2:]

# %%
df_val.head()
# Out:
#   CLM_S_Current CLM_S_Ideal CLM_S_all_mortality_zero CLM_S_all_mort_25_imp  \
# 0            12          12                       12                    12
# 1           NaN         NaN                      NaN                   NaN
# 2       2070822     2070822                  2070822               2070822
# 3       2070822     2070822                  2070822               2070822
# 4       1915971     1915971                  1915971               1915971
#
#   CLM_S_all_mort_50_imp CLM_S_all_mort_75_imp  CLM_S_mortality_zero_N  \
# 0                    12                    12                      12
# 1                   NaN                   NaN                     NaN
# 2               2070822               2070822                 2070822
# 3               2070822               2070822                 2070822
# 4               1915971               1915971                 1915971
#
#    CLM_S_mortality_zero_J  CLM_S_mortality_zero_AF  CLM_S_mortality_zero_AM  \
# ...

# %%
extras = '''
species: smallruminants
nruns: 10000\n
'''

for (col_name, col_data) in df_val.items():
    print(col_name) # yaml file
    filename = "./smallruminants/temp_smallruminants/" + col_name + ".yaml"
    file = open(filename, "a")
    header = f"##### {col_name} #####\n"
    file.write(header)
    file.write(extras)
    for idx, data in enumerate(col_data):
        line = ""
        if keys[idx].startswith("#"):
            line = keys[idx]
        elif keys[idx] == "nan":
            line = ""
        else:
            val = str(data)
            if ("/" in str(data)) and ("(" not in str(data)):
                nums = str(data).split("/")
                val = str(float(nums[0]) / float(nums[1]))
            # elif str(data) == "0.9/(12*4)":
            #     val = str(0.9 / (12 * 4))
            line = keys[idx] + ": " + val
        line = line + "\n"
        file.write(line)
        # print(line)
    file.close()
# Out:
# CLM_S_Current
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 2070822
#
# N_NM_t0: 2070822
#
# N_JF_t0: 1915971
#
# N_JM_t0: 1147386
#
# N_AF_t0: 14049629
#
# N_AM_t0: 3048715
#
#
#
# ## Growth rate N -> J and J-> A
#
# Beta: 0.16666666666666666
#
#
#
# # Fertility
#
# part: rpert(10000, 0.52, 0.67, 0.60)
#
# prolif: rtruncnorm(10000, 0, 3, 1.3, 0.15)
#
#
#
# # lactation
#
# prop_F_milked: 0
#
# lac_duration: 0
#
# avg_daily_yield_ltr: 0
#
# milk_value_ltr: 0
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaF : 0.0033333333333333335
#
# GammaM : 0.045000000000000005
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(1000, 0.09/6, 0.49/6, 0.2/6)
#
# AlphaJ: rpert(1000, 0.03/6, 0.30/6, 0.07/6)
#
# AlphaF: rpert(1000, 0.02/12, 0.13/12, 0.05/12)
#
# AlphaM: rpert(1000, 0.02/12, 0.17/12, 0.06/12)
#
#
#
# # Culls
#
# ...
