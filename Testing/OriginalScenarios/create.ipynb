# %%
import pandas as pd

# %%
excel_file = "./cattle/AHLE scenario parameters CATTLE.xlsx"

df = pd.read_excel(excel_file)
df.head(10)
# Out:
#                                AHLE Parameter              Notes  \
# 0  # for now ideal scenarios are just made up                NaN
# 1                                  Num_months                NaN
# 2                        # Initial population                NaN
# 3                                     N_NF_t0  # Neonatal female
# 4                                     N_NM_t0    # Neonatal male
# 5                                     N_JF_t0  # Juvenile female
# 6                                     N_JM_t0    # Juvenile male
# 7                                     N_AF_t0     # Adult female
# 8                                     N_AM_t0       # Adult male
# 9                                      N_O_t0                NaN
#
#   cattle_trial_CLM_current cattle_trial_CLM_all_mortality_zero  \
# 0                      NaN                                 NaN
# 1                       12                                  12
# 2                      NaN                                 NaN
# 3                  4185804                             4185804
# 4                  4658857                             4658857
# 5                  4472291                             4472291
# 6                  5481069                             5481069
# 7                 16726643                            16726643
# 8                  2159425                             2159425
# 9                 17363582                            17363582
#
#   cattle_trial_CLM_ideal cattle_trial_CLM_mortality_zero_N  \
# 0                    NaN                               NaN
# 1                     12                                12
# 2                    NaN                               NaN
# 3                4185804                           4185804
# 4                4658857                           4658857
# 5                4472291                           4472291
# 6                5481069                           5481069
# 7               16726643                          16726643
# 8                2159425                           2159425
# 9               17363582                          17363582
#
#   cattle_trial_CLM_mortality_zero_J cattle_trial_CLM_mortality_zero_AF  \
# 0                               NaN                                NaN
# 1                                12                                 12
# 2                               NaN                                NaN
# 3                           4185804                            4185804
# 4                           4658857                            4658857
# 5                           4472291                            4472291
# 6                           5481069                            5481069
# 7                          16726643                           16726643
# 8                           2159425                            2159425
# 9                          17363582                           17363582
#
#   cattle_trial_CLM_mortality_zero_AM cattle_trial_CLM_mortality_zero_O  ...  \
# 0                                NaN                               NaN  ...
# 1                                 12                                12  ...
# 2                                NaN                               NaN  ...
# 3                            4185804                           4185804  ...
# 4                            4658857                           4658857  ...
# 5                            4472291                           4472291  ...
# 6                            5481069                           5481069  ...
# 7                           16726643                          16726643  ...
# 8                            2159425                           2159425  ...
# 9                           17363582                          17363582  ...
#
#   cattle_trial_periurban_dairy_mortality_zero_AF  \
# 0                                            NaN
# 1                                             12
# 2                                            NaN
# 3                                  327592.454013
# 4                                          93598
# 5                                  444082.759862
# 6                                   47865.920223
# 7                                  913813.476978
# 8                                   39052.934912
# 9                                              0
#
#   cattle_trial_periurban_dairy_mortality_zero_AM  \
# 0                                            NaN
# 1                                             12
# 2                                            NaN
# 3                                  327592.454013
# 4                                          93598
# 5                                  444082.759862
# 6                                   47865.920223
# 7                                  913813.476978
# 8                                   39052.934912
# 9                                              0
#
#   cattle_trial_periurban_dairy_mortality_zero_O  \
# 0                                           NaN
# 1                                            12
# 2                                           NaN
# 3                                 327592.454013
# 4                                         93598
# 5                                 444082.759862
# 6                                  47865.920223
# 7                                 913813.476978
# 8                                  39052.934912
# 9                                             0
#
#   cattle_trial_periurban_dairy_ideal_NF cattle_trial_periurban_dairy_ideal_NM  \
# 0                                   NaN                                   NaN
# 1                                    12                                    12
# 2                                   NaN                                   NaN
# 3                         327592.454013                         327592.454013
# 4                                 93598                                 93598
# 5                         444082.759862                         444082.759862
# 6                          47865.920223                          47865.920223
# 7                         913813.476978                         913813.476978
# 8                          39052.934912                          39052.934912
# 9                                     0                                     0
#
#   cattle_trial_periurban_dairy_ideal_JF cattle_trial_periurban_dairy_ideal_JM  \
# 0                                   NaN                                   NaN
# 1                                    12                                    12
# 2                                   NaN                                   NaN
# 3                         327592.454013                         327592.454013
# 4                                 93598                                 93598
# 5                         444082.759862                         444082.759862
# 6                          47865.920223                          47865.920223
# 7                         913813.476978                         913813.476978
# 8                          39052.934912                          39052.934912
# 9                                     0                                     0
#
#   cattle_trial_periurban_dairy_ideal_AF cattle_trial_periurban_dairy_ideal_AM  \
# 0                                   NaN                                   NaN
# 1                                    12                                    12
# 2                                   NaN                                   NaN
# 3                         327592.454013                         327592.454013
# 4                                 93598                                 93598
# 5                         444082.759862                         444082.759862
# 6                          47865.920223                          47865.920223
# 7                         913813.476978                         913813.476978
# 8                          39052.934912                          39052.934912
# 9                                     0                                     0
#
#   cattle_trial_periurban_dairy_ideal_O
# 0                                  NaN
# 1                                   12
# 2                                  NaN
# 3                        327592.454013
# 4                                93598
# 5                        444082.759862
# 6                         47865.920223
# 7                        913813.476978
# 8                         39052.934912
# 9                                    0
#
# [10 rows x 47 columns]

# %%
keys = df["AHLE Parameter"].tolist()
keys = list(map(str, keys))
keys
# Out:
# ['# for now ideal scenarios are just made up',
#  'Num_months',
#  '# Initial population',
#  'N_NF_t0',
#  'N_NM_t0',
#  'N_JF_t0',
#  'N_JM_t0',
#  'N_AF_t0',
#  'N_AM_t0',
#  'N_O_t0',
#  '## Growth rate N -> J and J-> A',
#  'Beta_N',
#  'Beta_J',
#  'nan',
#  '# Fertility',
#  'part',
#  'prolif',
#  'nan',
#  '# lactation',
#  'prop_F_milked',
#  'lac_duration',
#  'avg_daily_yield_ltr',
#  'milk_value_ltr',
#  'nan',
#  '# draught power',
#  'castration_rate',
#  'draught_rate',
#  'draught_day_value',
#  'nan',
#  '# Offtake',
#  '## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0',
#  '## offtake must = offtake + dif between NNFt0 etc and NJF current',
#  'GammaNF',
#  'GammaNM',
#  'GammaJF',
#  'GammaJM',
#  'GammaAF',
#  'GammaAM ',
#  'GammaO',
#  'nan',
#  '# Mortality ## informed from META analysis',
#  'AlphaN',
#  'AlphaJ',
#  'AlphaF',
#  'AlphaM',
#  'AlphaO',
#  'nan',
#  '# Culls',
#  'CullF',
#  'CullM',
#  'CullO',
#  '## Production parameters (kg)',
#  'nan',
#  '# Liveweight conversion (kg) ## Informed from META analysis',
#  'lwNF  ',
#  'lwNM  ',
#  'lwJF ',
#  'lwJM ',
#  'lwAF ',
#  'lwAM ',
#  'lwO',
#  'nan',
#  '# carcase yeild',
#  'ccy ',
#  'nan',
#  '## Financial value of live animals',
#  '# Ethiopian Birr',
#  'fvNF ',
#  'fvJF ',
#  'fvAF',
#  'fvNM',
#  'fvJM',
#  'fvAM',
#  'fvO',
#  'nan',
#  'nan',
#  '## skin/hides  ',
#  '## parameters can be updated through expert opinion but adding options for flexibility here',
#  'hides_rate',
#  'hides_rate_mor',
#  'nan',
#  '# 1 usd per piece = 51 eth birr',
#  'hides_value',
#  'nan',
#  '# manure rate (kg produced/animal/day)',
#  'Man_N',
#  'Man_J',
#  'Man_A',
#  'nan',
#  '# 0.0125 USD / kg = 0.65 eth birr per kg 2021 price',
#  'Man_value',
#  'nan',
#  '## dry matter requirements as proportion of liveweight',
#  'DM_req_prpn_NF',
#  'DM_req_prpn_NM',
#  'DM_req_prpn_JF',
#  'DM_req_prpn_JM',
#  'DM_req_prpn_AF',
#  'DM_req_prpn_AM',
#  'DM_req_prpn_O',
#  'nan',
#  '## Proportion of livestock keepers that spend any money on feed',
#  '## NOTE Currently the same for all age*sex groups',
#  'prpn_lskeepers_purch_feed',
#  'nan',
#  '## For those spending any money on feed, the proportion of feed that is purchased',
#  '## NOTE Currently the same for all age*sex groups',
#  'prpn_feed_paid_for',
#  'nan',
#  '## Input parameters ## just example distributions for now',
#  'Feed_cost_kg',
#  'nan',
#  '## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia',
#  '## range 30-90%',
#  '## taking 70% as an estimate for this trial',
#  'DM_in_feed',
#  'nan',
#  '## Labour cost',
#  '## birr/head/month',
#  '## example code to change labour cost to selecting from distribution',
#  'Labour_cattle',
#  'lab_non_health',
#  'Labour_Oxen',
#  'Labour_dairy',
#  'nan',
#  '## Helath care costs',
#  '## birr/head/month',
#  '## this includes medicines and veterinary care',
#  '## and changing health care costs to select from distribution',
#  'Health_exp_prev',
#  'Health_exp_treatment',
#  'nan',
#  '## Capital costs',
#  '## for this we are using bank of Ethiopia inflation rate',
#  'Interest_rate',
#  'Infrastructure_per_head']

# %%
df_val = df.iloc[:,2:-1]

# %%
df_val.head()
# Out:
#   cattle_trial_CLM_current cattle_trial_CLM_all_mortality_zero  \
# 0                      NaN                                 NaN
# 1                       12                                  12
# 2                      NaN                                 NaN
# 3                  4185804                             4185804
# 4                  4658857                             4658857
#
#   cattle_trial_CLM_ideal cattle_trial_CLM_mortality_zero_N  \
# 0                    NaN                               NaN
# 1                     12                                12
# 2                    NaN                               NaN
# 3                4185804                           4185804
# 4                4658857                           4658857
#
#   cattle_trial_CLM_mortality_zero_J cattle_trial_CLM_mortality_zero_AF  \
# 0                               NaN                                NaN
# 1                                12                                 12
# 2                               NaN                                NaN
# 3                           4185804                            4185804
# 4                           4658857                            4658857
#
#   cattle_trial_CLM_mortality_zero_AM cattle_trial_CLM_mortality_zero_O  \
# 0                                NaN                               NaN
# 1                                 12                                12
# 2                                NaN                               NaN
# 3                            4185804                           4185804
# 4                            4658857                           4658857
#
#   cattle_trial_CLM_ideal_NF cattle_trial_CLM_ideal_NM  ...  \
# 0                       NaN                       NaN  ...
# 1                        12                        12  ...
# 2                       NaN                       NaN  ...
# 3                   4185804                   4185804  ...
# 4                   4658857                   4658857  ...
#
#   cattle_trial_periurban_dairy_mortality_zero_J  \
# 0                                           NaN
# 1                                            12
# 2                                           NaN
# 3                                 327592.454013
# 4                                         93598
#
#   cattle_trial_periurban_dairy_mortality_zero_AF  \
# 0                                            NaN
# 1                                             12
# 2                                            NaN
# 3                                  327592.454013
# 4                                          93598
#
#   cattle_trial_periurban_dairy_mortality_zero_AM  \
# 0                                            NaN
# 1                                             12
# 2                                            NaN
# 3                                  327592.454013
# 4                                          93598
#
#   cattle_trial_periurban_dairy_mortality_zero_O  \
# 0                                           NaN
# 1                                            12
# 2                                           NaN
# 3                                 327592.454013
# 4                                         93598
#
#   cattle_trial_periurban_dairy_ideal_NF cattle_trial_periurban_dairy_ideal_NM  \
# 0                                   NaN                                   NaN
# 1                                    12                                    12
# 2                                   NaN                                   NaN
# 3                         327592.454013                         327592.454013
# 4                                 93598                                 93598
#
#   cattle_trial_periurban_dairy_ideal_JF cattle_trial_periurban_dairy_ideal_JM  \
# 0                                   NaN                                   NaN
# 1                                    12                                    12
# 2                                   NaN                                   NaN
# 3                         327592.454013                         327592.454013
# 4                                 93598                                 93598
#
#   cattle_trial_periurban_dairy_ideal_AF cattle_trial_periurban_dairy_ideal_AM
# 0                                   NaN                                   NaN
# 1                                    12                                    12
# 2                                   NaN                                   NaN
# 3                         327592.454013                         327592.454013
# 4                                 93598                                 93598
#
# [5 rows x 44 columns]

# %%
extras = '''
species: cattle
nruns: 10000\n
'''

for (col_name, col_data) in df_val.items():
    print(col_name) # yaml file
    filename = "./tbp_cattle/" + col_name + ".yaml"
    file = open(filename, "a")
    header = f"##### {col_name} #####\n"
    file.write(header)
    file.write(extras)
    for idx, data in enumerate(col_data):
        line = ""
        if keys[idx].startswith("#"):
            line = keys[idx]
        elif keys[idx] == "nan":
            line = ""
        else:
            val = str(data)
            if ("/" in str(data)) and ("(" not in str(data)):
                nums = str(data).split("/")
                val = str(float(nums[0]) / float(nums[1]))
            elif str(data) == "0.9/(12*4)":
                val = str(0.9 / (12 * 4))
            line = keys[idx] + ": " + val
        line = line + "\n"
        file.write(line)
        print(line)
    file.close()
# Out:
# cattle_trial_CLM_current
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_all_mortality_zero
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: 0
#
# AlphaJ: 0
#
# AlphaF: 0
#
# AlphaM: 0
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.020833333333333332
#
# CullO: 0.020833333333333332
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.25
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_ideal
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.63, 0.75, 0.69)
#
# prolif: rpert (10000, 1, 2, 1.0001)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: rpert(10000, 75, 540, 330)
#
# avg_daily_yield_ltr: rpert(10000, 1, 8, 2.19)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.273972602739726
#
# draught_day_value: 150
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: 0
#
# AlphaJ: 0
#
# AlphaF: 0
#
# AlphaM: 0
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.020833333333333332
#
# CullO: 0.020833333333333332
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 150, 110)
#
# lwNM  : rpert(10000, 23, 180, 120)
#
# lwJF : rpert(10000, 90, 300, 180)
#
# lwJM : rpert(10000, 100, 350, 190)
#
# lwAF : rpert(10000, 150, 350, 240)
#
# lwAM : rpert(10000, 170, 450, 300)
#
# lwO: rpert(10000, 170, 450, 300)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, (10876+(0.2*10876)), (11616+(0.2*11616)), (11088+(0.2*11088)))
#
# fvJF : rpert(10000, (13200+(0.3*13200)), (17793+(0.3*17793)), (16896+(0.3*16896)))
#
# fvAF: rpert(10000,  (18480+1848), (27825+2782), (23337+2333))
#
# fvNM: rpert(10000, (9345+934), (17793+1779), (9556+955))
#
# fvJM: rpert(10000, (17160), (20750), (20592))
#
# fvAM: rpert(10000, (15840+(0.2*15840)), (49104+(0.2*49104)), (33475+(0.2*33475)))
#
# fvO: rpert(10000, (15840+(0.2*15840)), (49104+(0.2*49104)), (33475+(0.2*33475)))
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.25
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 0.85
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: 0
#
# Health_exp_treatment: 0
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_mortality_zero_N
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: 0
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_mortality_zero_J
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: 0
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_mortality_zero_AF
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: 0
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_mortality_zero_AM
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: 0
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_mortality_zero_O
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_ideal_NF
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: 0
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 150, 110)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, (10876+(0.2*10876)), (11616+(0.2*11616)), (11088+(0.2*11088)))
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_ideal_NM
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: 0
#
# AlphaJ: rpert(10000, 0.06/12, 0.09/12, 0.075/12)
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 180, 120)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, (9345+934), (17793+1779), (9556+955))
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_ideal_JF
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: 0
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 300, 180)
#
# lwJM : rpert(10000, 100, 320, 170)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, (13200+(0.3*13200)), (17793+(0.3*17793)), (16896+(0.3*16896)))
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, 17160, 20750, 20592)
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (58/12), (58/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_CLM_ideal_JM
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 4185804
#
# N_NM_t0: 4658857
#
# N_JF_t0: 4472291
#
# N_JM_t0: 5481069
#
# N_AF_t0: 16726643
#
# N_AM_t0: 2159425
#
# N_O_t0: 17363582
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: rpert(10000, 0.49, 0.56, 0.525)
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: 210
#
# avg_daily_yield_ltr: rpert(10000, 1.45, 1.482, 1.47)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0.01875
#
# draught_rate: 0.2191780821917808
#
# draught_day_value: 136.7
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0
#
# GammaNM: 0
#
# GammaJF: 0.0015416666666666667
#
# GammaJM: 0
#
# GammaAF: 0.005883333333333333
#
# GammaAM : 0.0075
#
# GammaO: 0.0075
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.09/12, 0.26/12, 0.12/12)
#
# AlphaJ: 0
#
# AlphaF: rpert(10000, 0.02/12, 0.02/12, 0.02/12)
#
# AlphaM: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaO: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.016666666666666666
#
# CullO: 0.016666666666666666
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : rpert(10000, 22, 120, 90)
#
# lwNM  : rpert(10000, 23, 150, 90)
#
# lwJF : rpert(10000, 90, 280, 160)
#
# lwJM : rpert(10000, 100, 350, 190)
#
# lwAF : rpert(10000, 150, 340, 240)
#
# lwAM : rpert(10000, 170, 400, 255)
#
# lwO: rpert(10000, 170, 400, 255)
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 10876, 11616, 11088)
#
# fvJF : rpert(10000, 13200, 17793, 16896)
#
# fvAF: rpert(10000,  18480,  27825,  23337)
#
# fvNM: rpert(10000, 9345, 17793, 9556)
#
# fvJM: rpert(10000, (17160), (20750), (20592))
#
# fvAM: rpert(10000, 15840,  49104, 33475)
#
# fvO: rpert(10000, 15840,  49104, 33475)
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 0.25
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: rpert(10000, (260/12), (649/12), (368/12))
#
# ...
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: 0
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (57/12), (57/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_periurban_dairy_ideal_JF
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 327592.45401257667
#
# N_NM_t0: 93598
#
# N_JF_t0: 444082.7598620669
#
# N_JM_t0: 47865.920223466295
#
# N_AF_t0: 913813.476977538
#
# N_AM_t0: 39052.93491177515
#
# N_O_t0: 0
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: 0.87
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: rpert(10000, 200, 380, 290)
#
# avg_daily_yield_ltr: rpert(10000, 8.3, 18, 11.7)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0
#
# draught_rate: 0
#
# draught_day_value: 0
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0.009166666666666667
#
# GammaNM: 0.059166666666666666
#
# GammaJF: 0.021666666666666667
#
# GammaJM: 0
#
# GammaAF: 0.023333333333333334
#
# GammaAM : 0.004166666666666667
#
# GammaO: 0.0
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.07/12, 0.07/12, 0.07/12)
#
# AlphaJ: 0
#
# AlphaF: 0.0025
#
# AlphaM: 0.0025
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.009259259259259259
#
# CullO: 0
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : 147
#
# lwNM  : 147
#
# lwJF : rpert(10000, 190, 450, 250)
#
# lwJM : 375
#
# lwAF : 550
#
# lwAM : 550
#
# lwO: 0
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 11116, 11116, 11116)
#
# fvJF : rpert(10000, (16938+(0.1*16938)), (16938+(0.1*16938)), (16938+(0.1*16938)))
#
# fvAF: rpert(10000,  23396,  23396,  23396)
#
# fvNM: rpert(10000, 9581, 9581, 9581)
#
# fvJM: rpert(10000, 20644, 20644, 20644)
#
# fvAM: rpert(10000, 38324,  38324, 38324)
#
# fvO: 0
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 1
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: 0
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (57/12), (57/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_periurban_dairy_ideal_JM
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 327592.45401257667
#
# N_NM_t0: 93598
#
# N_JF_t0: 444082.7598620669
#
# N_JM_t0: 47865.920223466295
#
# N_AF_t0: 913813.476977538
#
# N_AM_t0: 39052.93491177515
#
# N_O_t0: 0
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: 0.87
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: rpert(10000, 200, 380, 290)
#
# avg_daily_yield_ltr: rpert(10000, 8.3, 18, 11.7)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0
#
# draught_rate: 0
#
# draught_day_value: 0
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0.009166666666666667
#
# GammaNM: 0.059166666666666666
#
# GammaJF: 0.021666666666666667
#
# GammaJM: 0
#
# GammaAF: 0.023333333333333334
#
# GammaAM : 0.004166666666666667
#
# GammaO: 0.0
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.07/12, 0.07/12, 0.07/12)
#
# AlphaJ: 0
#
# AlphaF: 0.0025
#
# AlphaM: 0.0025
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.009259259259259259
#
# CullO: 0
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : 147
#
# lwNM  : 147
#
# lwJF : 375
#
# lwJM : rpert(10000, 195, 500, 400)
#
# lwAF : 550
#
# lwAM : 550
#
# lwO: 0
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 11116, 11116, 11116)
#
# fvJF : rpert(10000, 16938, 16938, 16938)
#
# fvAF: rpert(10000,  23396,  23396,  23396)
#
# fvNM: rpert(10000, 9581, 9581, 9581)
#
# fvJM: rpert(10000, (20644+(0*20644)), (20644+(0*20644)), (20644+(0*20644)))
#
# fvAM: rpert(10000, 38324,  38324, 38324)
#
# fvO: 0
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 1
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: 0
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (57/12), (57/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_periurban_dairy_ideal_AF
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 327592.45401257667
#
# N_NM_t0: 93598
#
# N_JF_t0: 444082.7598620669
#
# N_JM_t0: 47865.920223466295
#
# N_AF_t0: 913813.476977538
#
# N_AM_t0: 39052.93491177515
#
# N_O_t0: 0
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: 1
#
# prolif: rpert(10000, 1, 2, 1.0001)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: rpert(10000, 90, 450, 261)
#
# avg_daily_yield_ltr: rpert(10000, 2, 45, 10.5)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0
#
# draught_rate: 0
#
# draught_day_value: 0
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0.009166666666666667
#
# GammaNM: 0.059166666666666666
#
# GammaJF: 0.021666666666666667
#
# GammaJM: 0
#
# GammaAF: 0.023333333333333334
#
# GammaAM : 0.004166666666666667
#
# GammaO: 0.0
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.07/12, 0.07/12, 0.07/12)
#
# AlphaJ: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaF: 0
#
# AlphaM: 0.0025
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.009259259259259259
#
# CullO: 0
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : 147
#
# lwNM  : 147
#
# lwJF : 375
#
# lwJM : 375
#
# lwAF : rpert(10000, 250, 600, 550)
#
# lwAM : 550
#
# lwO: 0
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 11116, 11116, 11116)
#
# fvJF : rpert(10000, 16938, 16938, 16938)
#
# fvAF: rpert(10000, (23396+(0*23396)),  (23396+(0*23396)),  (23396+(0*23396)))
#
# fvNM: rpert(10000, 9581, 9581, 9581)
#
# fvJM: rpert(10000, 20644, 20644, 20644)
#
# fvAM: rpert(10000, 38324,  38324, 38324)
#
# fvO: 0
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 1
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: 0
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (57/12), (57/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
#
# cattle_trial_periurban_dairy_ideal_AM
# # for now ideal scenarios are just made up
#
# Num_months: 12
#
# # Initial population
#
# N_NF_t0: 327592.45401257667
#
# N_NM_t0: 93598
#
# N_JF_t0: 444082.7598620669
#
# N_JM_t0: 47865.920223466295
#
# N_AF_t0: 913813.476977538
#
# N_AM_t0: 39052.93491177515
#
# N_O_t0: 0
#
# ## Growth rate N -> J and J-> A
#
# Beta_N: 0.08333333333333333
#
# Beta_J: 0.041666666666666664
#
#
#
# # Fertility
#
# part: 0.87
#
# prolif: rtruncnorm(10000, 0, 1.1, 1, 0.0015)
#
#
#
# # lactation
#
# prop_F_milked: 1
#
# lac_duration: rpert(10000, 200, 380, 290)
#
# avg_daily_yield_ltr: rpert(10000, 8.3, 18, 11.7)
#
# milk_value_ltr: 31
#
#
#
# # draught power
#
# castration_rate: 0
#
# draught_rate: 0
#
# draught_day_value: 0
#
#
#
# # Offtake
#
# ## Currently fixed, but, should this be dependant on new pop size, to keep pop size as it was at t0
#
# ## offtake must = offtake + dif between NNFt0 etc and NJF current
#
# GammaNF: 0.009166666666666667
#
# GammaNM: 0.059166666666666666
#
# GammaJF: 0.021666666666666667
#
# GammaJM: 0
#
# GammaAF: 0.023333333333333334
#
# GammaAM : 0.004166666666666667
#
# GammaO: 0.0
#
#
#
# # Mortality ## informed from META analysis
#
# AlphaN: rpert(10000, 0.07/12, 0.07/12, 0.07/12)
#
# AlphaJ: rpert(10000, 0.01/12, 0.01/12, 0.01/12)
#
# AlphaF: 0.0025
#
# AlphaM: 0
#
# AlphaO: 0
#
#
#
# # Culls
#
# CullF: 0.009259259259259259
#
# CullM: 0.009259259259259259
#
# CullO: 0
#
# ## Production parameters (kg)
#
#
#
# # Liveweight conversion (kg) ## Informed from META analysis
#
# lwNF  : 147
#
# lwNM  : 147
#
# lwJF : 375
#
# lwJM : 375
#
# lwAF : 550
#
# lwAM : rpert(10000, 255, 650, 550)
#
# lwO: 0
#
#
#
# # carcase yeild
#
# ccy : 0.5
#
#
#
# ## Financial value of live animals
#
# # Ethiopian Birr
#
# fvNF : rpert(10000, 11116, 11116, 11116)
#
# fvJF : rpert(10000, 16938, 16938, 16938)
#
# fvAF: rpert(10000,  23396,  23396,  23396)
#
# fvNM: rpert(10000, 9581, 9581, 9581)
#
# fvJM: rpert(10000, 20644, 20644, 20644)
#
# fvAM: rpert(10000, (38324+(0*38324)), (38324+(0*38324)), (38324+(0*38324)))
#
# fvO: 0
#
#
#
#
#
# ## skin/hides
#
# ## parameters can be updated through expert opinion but adding options for flexibility here
#
# hides_rate: 1
#
# hides_rate_mor: 0.5
#
#
#
# # 1 usd per piece = 51 eth birr
#
# hides_value: rpert(10000, (2.19*12.5), (9*12.5), (5.4*12.5))
#
#
#
# # manure rate (kg produced/animal/day)
#
# Man_N: rpert(10000, 0.5, 0.8, 0.65)
#
# Man_J: rpert(10000, 0.8,  1.5, 1.15)
#
# Man_A: rpert(10000,  1.5,2.3, 1.9)
#
#
#
# # 0.0125 USD / kg = 0.65 eth birr per kg 2021 price
#
# Man_value: 0.5
#
#
#
# ## dry matter requirements as proportion of liveweight
#
# DM_req_prpn_NF: 0.026
#
# DM_req_prpn_NM: 0.026
#
# DM_req_prpn_JF: 0.026
#
# DM_req_prpn_JM: 0.026
#
# DM_req_prpn_AF: 0.026
#
# DM_req_prpn_AM: 0.026
#
# DM_req_prpn_O: 0.026
#
#
#
# ## Proportion of livestock keepers that spend any money on feed
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_lskeepers_purch_feed: 1
#
#
#
# ## For those spending any money on feed, the proportion of feed that is purchased
#
# ## NOTE Currently the same for all age*sex groups
#
# prpn_feed_paid_for: 0.5
#
#
#
# ## Input parameters ## just example distributions for now
#
# Feed_cost_kg: rpert(10000, 2.5, 6.5, 3.46)
#
#
#
# ## variable results for the amount of dry matter in wheat and barley and tef in Ethiopia
#
# ## range 30-90%
#
# ## taking 70% as an estimate for this trial
#
# DM_in_feed: rpert(10000, 0.85, 0.95, 0.9)
#
#
#
# ## Labour cost
#
# ## birr/head/month
#
# ## example code to change labour cost to selecting from distribution
#
# Labour_cattle: rpert(10000, (260/12), (649/12), (368/12))
#
# lab_non_health: 1
#
# Labour_Oxen: 0
#
# Labour_dairy: rpert(10000, (260/12), (649/12), (368/12))
#
#
#
# ## Helath care costs
#
# ## birr/head/month
#
# ## this includes medicines and veterinary care
#
# ## and changing health care costs to select from distribution
#
# Health_exp_prev: runif(10000, (57/12), (57/12))
#
# Health_exp_treatment: runif(10000, (58/12), (58/12))
#
#
#
# ## Capital costs
#
# ## for this we are using bank of Ethiopia inflation rate
#
# Interest_rate: 0
#
# Infrastructure_per_head: 1
